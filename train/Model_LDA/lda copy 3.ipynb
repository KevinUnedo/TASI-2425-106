# %% [markdown]
# Import Libraries and Configure Logging

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim import corpora
from gensim.models import LdaModel, CoherenceModel
from gensim.models.phrases import Phrases, Phraser
from sklearn.feature_extraction.text import TfidfVectorizer
from rake_nltk import Rake, Metric
from collections import Counter
from tqdm import tqdm
import logging
import random
import os
from scipy.stats import entropy

# Setup logging
logging.basicConfig(
    filename='lda_output.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logging.getLogger('gensim').setLevel(logging.WARNING)

# Download NLTK data
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
# Out:
# True

# %% [markdown]
# Initialize NLP Tools and Stopwords

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Domain-specific stopwords
custom_stopwords = {
    'allow', 'class', 'available', 'part', 'case', 'lead', 'shall', 'product', 'operate',
    'operational', 'result', 'input', 'dependent', 'preference', 'item', 'without', 'let',
    'returned', 'message', 'every', 'system', 'run', 'fully', 'major', 'reasonable',
    'software', 'user', 'able', 'ability', 'support', 'year', 'expected', 'must',
    'information', 'data', 'use', 'using', 'provide', 'successfully', 'one', 'waiter',
    'include', 'accommodate', 'event', 'technique', 'recent', 'administrator', 'search',
    'add', 'allows', 'achieve', 'way', 'outside', 'release', 'launch', 'allowed', 'entered',
    'within', 'first', 'new', 'izogn', 'wcs', 'course', 'time', 'help', 'learn', 'ccr', 'cma'
    'player', 'meeting', 'lab', 'staff', 'member', 'nursing', 'clinical', 'unix', 'palm', 'either'
}
stop_words.update(custom_stopwords)

# Review-specific stopwords
review_stopwords = {
    'review', 'star', 'rating', 'good', 'great', 'course', 'learn', 'learning',
    'would', 'like', 'could', 'one', 'bit', 'week', 'think', 'much', 'really',
    'lot', 'new', 'thank', 'thanks', 'many', 'well', 'also', 'get', 'time',
    'truly', 'even', 'make', 'see', 'content', 'material', 'class', 'work',
    'way', 'understand', 'information', 'helpful', 'useful', 'knowledge',
    'day', 'help', 'easy'
}
stop_words.update(review_stopwords)

# %% [markdown]
# Load PROMISE Data

# %%
def load_promise_data(file_path):
    try:
        df = pd.read_csv(file_path)
        logging.info(f"Successfully loaded PROMISE data from {file_path}")
        return df
    except FileNotFoundError:
        logging.error(f"PROMISE data file not found at {file_path}")
        raise
    except Exception as e:
        logging.error(f"Error loading PROMISE data: {e}")
        raise

promise_data_path = '../../datasets/PROMISE_exp_cleaned.csv'
promise_df = load_promise_data(promise_data_path)

# %% [markdown]
# Aggregate Data by Category

# %%
logging.info("Started aggregating PROMISE data by category")
category_texts = promise_df.groupby('_class_')['cleaned_text'].apply(lambda x: ' '.join(x)).to_dict()
for category, text in category_texts.items():
    word_count = len(text.split())
    logging.info(f"Category {category}: {word_count} words")
    print(f"Category {category}: {word_count} words")
    if word_count < 50:
        logging.warning(f"Category {category} has short text")
        print(f"Warning: Category {category} has short text ({word_count} words). Consider reviewing data.")
    if word_count == 0:
        logging.error(f"Category {category} has empty text")
        raise ValueError(f"Category {category} has empty text. Check data filtering.")
# Out:
# Category F: 3041 words
# Category FT: 129 words
# Category PE: 559 words
# Category PO: 58 words
# Category SC: 144 words
# Category SE: 951 words
# Category US: 653 words

# %% [markdown]
# Extract Seed Words

# %%
logging.info("Started extracting seed words")
seed_words = {}
target_word_count = 20
category_word_scores = {}

# %% [markdown]
# Extract RAKE phrases per document

# %%
logging.info("Started extracting RAKE phrases for individual documents")
document_phrases = []
for idx, row in tqdm(promise_df.iterrows(), total=len(promise_df), desc="Processing documents"):
    text = row['cleaned_text']
    category = row['_class_']
    
    # Skip empty or invalid texts
    if not isinstance(text, str) or len(text.strip()) == 0:
        logging.warning(f"Empty or invalid text at index {idx} for category {category}")
        continue
    
    # Initialize RAKE
    rake = Rake(
        stopwords=stop_words,
        min_length=2,
        max_length=2,
        ranking_metric=Metric.DEGREE_TO_FREQUENCY_RATIO,
        include_repeated_phrases=False
    )
    
    # Extract phrases
    rake.extract_keywords_from_text(text)
    phrases = rake.get_ranked_phrases_with_scores()
    
    # Store phrases with document index and category
    for score, phrase in phrases:
        document_phrases.append({
            'doc_id': idx,
            'category': category,
            'phrase': phrase,
            'score': score
        })
    
    # Log progress
    logging.info(f"Processed document {idx} in category {category}: {len(phrases)} phrases extracted")

phrases_df = pd.DataFrame(document_phrases)
logging.info(f"Total phrases extracted across all documents: {len(phrases_df)}")
# Out:
# Processing documents: 100%|██████████| 773/773 [00:00<00:00, 3348.68it/s]

# %% [markdown]
# Combine TF-IDF and RAKE for seed words

# %%
for category, text in category_texts.items():
    # TF-IDF Extraction (focus on single terms)
    vectorizer = TfidfVectorizer(
        max_features=200,
        ngram_range=(1, 1),  # Only unigrams
        stop_words=list(stop_words),
        min_df=1,
        sublinear_tf=True
    )
    tfidf_matrix = vectorizer.fit_transform([text])
    tfidf_terms = vectorizer.get_feature_names_out()
    tfidf_scores = tfidf_matrix.toarray()[0]
    tfidf_term_scores = {term: score for term, score in zip(tfidf_terms, tfidf_scores) if score > 0.03}
    logging.info(f"Category {category}: {len(tfidf_term_scores)} TF-IDF single terms extracted")

    # RAKE Phrase Extraction for Category (focus on phrases)
    category_phrases = phrases_df[phrases_df['category'] == category][['phrase', 'score']]
    aggregated_phrases = category_phrases.groupby('phrase').agg({'score': 'sum'}).reset_index()
    aggregated_phrases = aggregated_phrases.sort_values(by='score', ascending=False)
    logging.info(f"Category {category}: {len(aggregated_phrases)} RAKE phrases aggregated")

    # Convert RAKE phrases to terms (only multi-word phrases)
    rake_terms = []
    rake_term_scores = {}
    for _, row in aggregated_phrases.iterrows():
        phrase = row['phrase']
        score = row['score']
        words = [lemmatizer.lemmatize(word) for word in phrase.split()]
        if len(words) > 1:  # Only include multi-word phrases
            phrase_term = '_'.join(words)  # Join phrases with underscores
            rake_terms.append(phrase_term)
            rake_term_scores[phrase_term] = score
    logging.info(f"Category {category}: {len(rake_terms)} RAKE phrase terms extracted")

    # Combine TF-IDF (single terms) and RAKE (phrases)
    combined_terms = list(set(tfidf_terms) | set(rake_terms))
    logging.info(f"Category {category}: {len(combined_terms)} combined terms before filtering")

    # Filter terms to ensure single words from TF-IDF and phrases from RAKE
    filtered_terms = [
        term for term in combined_terms
        if term not in stop_words
        and len(term.replace('_', '')) > 2  # Allow short phrases
        and (
            ('_' not in term and tfidf_term_scores.get(term, 0) > 0.03) or  # Single words from TF-IDF
            ('_' in term and term in rake_term_scores)  # Phrases from RAKE
        )
    ]
    logging.info(f"Category {category}: {len(filtered_terms)} terms after filtering")

    # Score terms
    term_scores = {}
    word_freq = Counter(text.split())
    total_freq = sum(word_freq.values())
    max_rake_score = aggregated_phrases['score'].max() if not aggregated_phrases.empty else 1.0
    for term in filtered_terms:
        tfidf_score = tfidf_term_scores.get(term, 0)
        rake_score = rake_term_scores.get(term, 0)
        combined_score = 0.9 * tfidf_score + 0.1 * (rake_score / max_rake_score)
        term_scores[term] = combined_score
        logging.info(f"Category {category}: Term '{term}' - TF-IDF: {tfidf_score:.4f}, RAKE: {rake_score:.4f}, Combined: {combined_score:.4f}")

    # Ensure a mix of single words and phrases
    sorted_terms = sorted(term_scores.items(), key=lambda x: x[1], reverse=True)
    phrases = [(term, score) for term, score in sorted_terms if '_' in term][:10]  # Up to 10 phrases
    single_words = [(term, score) for term, score in sorted_terms if '_' not in term][:10]  # Up to 10 single words
    final_terms = phrases + single_words
    final_terms = sorted(final_terms, key=lambda x: x[1], reverse=True)[:target_word_count]
    seed_words[category] = [term for term, _ in final_terms]
    category_word_scores[category] = term_scores
    logging.info(f"Category {category}: Top {len(seed_words[category])} seed words selected: {seed_words[category]}")

# %% [markdown]
# Deduplicate and Finalize Seed Words

# %%
logging.info("Started deduplicating seed words")
final_seed_words = {category: [] for category in seed_words}
word_to_category = {}
word_to_score = {}

all_terms = []
for category, words in seed_words.items():
    for word in words:
        score = category_word_scores[category].get(word, 0)
        all_terms.append((word, category, score))

all_terms.sort(key=lambda x: x[2], reverse=True)

for word, category, score in all_terms:
    if word not in word_to_category:
        final_seed_words[category].append(word)
        word_to_category[word] = category
        word_to_score[word] = score

for category in final_seed_words:
    current_words = final_seed_words[category]
    remaining_slots = target_word_count - len(current_words)
    if remaining_slots > 0:
        available_terms = [
            (term, score) for term, score in sorted(category_word_scores[category].items(), key=lambda x: x[1], reverse=True)
            if term not in word_to_category and score > 0.04
        ]
        final_seed_words[category].extend(term for term, _ in available_terms[:remaining_slots])
    final_seed_words[category] = final_seed_words[category][:target_word_count]

# %% [markdown]
# Validate and Save Seed Words

# %%
logging.info("Validating seed words")
print("\nSeed Words by Category:")
for category, words in final_seed_words.items():
    logging.info(f"Category: {category} -> Seed Words ({len(words)}): {words}")
    print(f"Category: {category} -> Seed Words ({len(words)}): {words}")

word_overlap = {}
for category, words in final_seed_words.items():
    for word in words:
        if word not in word_overlap:
            word_overlap[word] = []
        word_overlap[word].append(category)
overlap_words = {word: cats for word, cats in word_overlap.items() if len(cats) > 1}
if overlap_words:
    logging.warning("Overlapping words detected")
    print("\nWarning: Overlapping words detected:")
    for word, cats in overlap_words.items():
        logging.warning(f"Word '{word}' appears in {cats}")
        print(f"Word '{word}' appears in {cats}")
else:
    logging.info("No overlapping words detected")
    print("\nNo overlapping words detected.")

seed_words_df = pd.DataFrame([(cat, word) for cat, words in final_seed_words.items() for word in words], columns=['Category', 'SeedWord'])
seed_words_path = '../../datasets/seed_words.csv'
seed_words_df.to_csv(seed_words_path, index=False)
logging.info(f"Seed words saved to {seed_words_path}")
print(f"\nSeed words saved to {seed_words_path}")
# Out:
# Seed Words by Category:
# Category: F -> Seed Words (20): ['player', 'display', 'collision_estimate', 'program', 'request', 'student', 'view', 'list', 'site', 'modify_relating', 'estimator_recycled', 'used_estimate', 'scheduler_reschedule', 'shopping_cart', 'vehicle_vehicle', 'sign_creating', 'planning_purpose', 'specify_custom', 'order', 'game']
# Category: FT -> Seed Words (20): ['fault', 'failure', 'reliability', 'database', 'robust', 'website', 'tablet', 'loss', 'filesystems', 'tolerance', 'high_number', 'report_appointment', 'warn_eca', 'malicious', 'continue', 'crash', 'main', 'flag', 'compensatory', 'less']
# Category: PE -> Seed Words (20): ['second', 'response', 'minute', 'load', 'take', 'longer', 'connection', 'application', 'take_min', 'depends_medium', 'second_poll', 'second_submits', 'display_confirmation', 'website_minute', 'performance_degradation', 'application_concurrent', 'maximum_second', 'movie', 'complete', 'performance']
# Category: PO -> Seed Words (20): ['web', 'window', 'operating', 'environment', 'compatible', 'portable', 'platform', 'browser', 'therefore', 'end', 'window_operating', 'end_may', 'window_linux', 'function_browser', 'window_server', 'interface', 'android', 'popular', 'usable', 'wide']
# Category: SC -> Seed Words (20): ['simultaneous', 'number', 'capable', 'handle', 'server', 'concurrent', 'hour', 'per', 'streaming', 'transaction', 'record_per', 'capable_processing', 'cater_simultaneous', 'scale_concurrent', 'customer_installation', 'scheduling_minimum', 'handle_simultaneous', 'number_grow', 'multiple_remote', 'program_curriculum']
# Category: SE -> Seed Words (20): ['access', 'customer', 'password', 'authorized', 'ensure', 'login', 'security', 'log', 'secured_database', 'role', 'audit_report', 'site_detail', 'people_access', 'authenticated_authorized', 'access_constraint', 'valid_invalid', 'trusted_trusted', 'viewing_period', 'access_attempt', 'secure']
# Category: US -> Seed Words (20): ['training', 'page', 'report', 'language', 'dispute', 'intuitive', 'used_novice', 'dba_two', 'feel_satisfied', 'added_minute', 'familiar_website', 'identification_dispute', 'log_minute', 'feedback_necessary', 'multi_language', 'interface_friendly', 'realtor', 'icon_toolbars', 'mouse_keyboard', 'manage_scheduling']
#
# No overlapping words detected.
#
# Seed words saved to ../../datasets/seed_words.csv

# %% [markdown]
# Load Seed Words

# %%
def load_seed_words_from_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        seed_words = df.groupby('Category')['SeedWord'].apply(list).to_dict()
        logging.info(f"Successfully loaded seed words from {file_path}")
        return seed_words
    except FileNotFoundError:
        logging.error(f"Seed words file not found at {file_path}")
        raise
    except Exception as e:
        logging.error(f"Error loading seed words: {e}")
        raise

seed_words = load_seed_words_from_csv(seed_words_path)
seed_word_set = set(word for words in seed_words.values() for word in words)
stop_words = stop_words - seed_word_set

# %% [markdown]
# Define Preprocessing Function

# %%
# Adjust preprocessing to preserve seed word components
seed_word_components = set(word for seed in seed_word_set for word in seed.replace('_', ' ').split())
def preprocess(text):
    if not isinstance(text, str) or not text.strip():
        return []
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = text.split()
    tokens = [
        lemmatizer.lemmatize(word) for word in tokens
        if (word not in stop_words or word in seed_word_components) and len(word) > 2
    ]
    return tokens

# %% [markdown]
# Load and Preprocess Review Data

# %%
input_path = '../../datasets/review_train.csv'
output_path = '../../datasets/selected_pseudo_labeled.csv'
threshold = 0.8
entropy_threshold = 1.0  # For filtering noisy samples

os.makedirs('models', exist_ok=True)

logging.info("Started loading review data")
df = pd.read_csv(input_path)
df = df[['processed_reviews']].copy()
df['processed_reviews'] = df['processed_reviews'].fillna("")
logging.info("Completed loading review data")

logging.info("Started preprocessing reviews")
tqdm.pandas()
tokenized_reviews = df['processed_reviews'].progress_apply(preprocess)
valid_indices = [i for i, tokens in enumerate(tokenized_reviews) if tokens]
tokenized_reviews = [tokens for tokens in tokenized_reviews if tokens]
if not tokenized_reviews:
    raise ValueError("No valid reviews after preprocessing.")
logging.info("Completed preprocessing reviews")
filtered_df = df.iloc[valid_indices].copy()
logging.info(f"Filtered DataFrame to {len(filtered_df)} valid reviews")
# Out:
# 100%|██████████| 286518/286518 [00:10<00:00, 28321.61it/s]

# %% [markdown]
# Detect Bigrams

# %%
logging.info("Started detecting bigrams")
sample_size = min(200000, len(tokenized_reviews))
sampled_reviews = random.sample(tokenized_reviews, sample_size) if sample_size < len(tokenized_reviews) else tokenized_reviews
bigram_model = Phrases(sampled_reviews, min_count=5, threshold=0.3, scoring='npmi')
seed_bigrams = [word.split('_') for word in seed_word_set if '_' in word]
bigram_model.add_vocab(seed_bigrams)
bigram_phraser = Phraser(bigram_model)
logging.info("Started applying bigrams")
tokenized_reviews = [bigram_phraser[tokens] for tokens in tokenized_reviews]
logging.info("Completed applying bigrams")

# %% [markdown]
# Create Dictionary and Check Seed Words

# %%
# Create dictionary and force include seed words
logging.info("Started creating dictionary")
dictionary = corpora.Dictionary(tokenized_reviews)
dictionary.filter_extremes(no_below=1, no_above=0.95)
logging.info("Completed creating dictionary")

logging.info("Checking seed word presence in corpus")
all_seed_words = set(word for words in seed_words.values() for word in words)
# Corpus words should include bigram phrases as single tokens
corpus_words = set(word for review in tokenized_reviews for word in review)  # tokenized_reviews already has bigrams applied
missing_in_corpus = all_seed_words - corpus_words

if missing_in_corpus:
    print(f"WARNING: {len(missing_in_corpus)} seed words are NOT present in the corpus:")
    print("Missing seed words and suggested near-matches:")
    for word in sorted(list(missing_in_corpus)):
        # For phrases (containing '_'), compare against other phrases; for single words, compare against single words
        if '_' in word:
            # Only compare against phrases (tokens with '_') in corpus
            near_matches = [
                w for w in corpus_words
                if '_' in w and (
                    lemmatizer.lemmatize(word.replace('_', ' ')) in w.replace('_', ' ') or
                    w.replace('_', ' ') in lemmatizer.lemmatize(word.replace('_', ' '))
                )
            ][:5]
        else:
            # For single words, compare against single words (no '_')
            near_matches = [
                w for w in corpus_words
                if '_' not in w and (
                    lemmatizer.lemmatize(word) in w or w in lemmatizer.lemmatize(word)
                )
            ][:5]
        print(f"  - '{word}': Near-matches = {near_matches if near_matches else 'None'}")
    logging.warning(f"{len(missing_in_corpus)} seed words not found in corpus")
else:
    print("SUCCESS: All seed words are present in the corpus.")
print("--------------------------------------------------\n")

print("\n--- Checking Seed Word Survival in Dictionary ---")
vocabulary = set(dictionary.token2id.keys())
missing_words = all_seed_words - vocabulary
if missing_words:
    print(f"WARNING: {len(missing_words)} seed words are NOT in the dictionary after filtering and will be ignored:")
    print(sorted(list(missing_words))[:20])
    if len(missing_words) > 20:
        print(f"... and {len(missing_words) - 20} more.")
else:
    print("SUCCESS: All seed words survived the dictionary filtering process.")
print("--------------------------------------------------\n")
# Out:
# WARNING: 63 seed words are NOT present in the corpus:
# Missing seed words and suggested near-matches:
#   - 'access_attempt': Near-matches = None
#   - 'access_constraint': Near-matches = None
#   - 'added_minute': Near-matches = None
#   - 'application_concurrent': Near-matches = None
#   - 'audit_report': Near-matches = None
#   - 'authenticated_authorized': Near-matches = None
#   - 'capable_processing': Near-matches = None
#   - 'cater_simultaneous': Near-matches = None
#   - 'collision_estimate': Near-matches = None
#   - 'customer_installation': Near-matches = None
#   - 'database': Near-matches = ['aba', 'ba', 'base', 'da', 'as']
#   - 'dba_two': Near-matches = None
#   - 'depends_medium': Near-matches = None
#   - 'display_confirmation': Near-matches = None
#   - 'end_may': Near-matches = None
#   - 'estimator_recycled': Near-matches = None
#   - 'familiar_website': Near-matches = None
#   - 'feedback_necessary': Near-matches = None
#   - 'feel_satisfied': Near-matches = None
#   - 'filesystems': Near-matches = ['es', 'file', 'stem']
#   - 'function_browser': Near-matches = None
#   - 'handle_simultaneous': Near-matches = None
#   - 'high_number': Near-matches = None
#   - 'icon_toolbars': Near-matches = None
#   - 'identification_dispute': Near-matches = None
#   - 'interface_friendly': Near-matches = None
#   - 'log_minute': Near-matches = None
#   - 'manage_scheduling': Near-matches = None
#   - 'maximum_second': Near-matches = None
#   - 'modify_relating': Near-matches = None
#   - 'mouse_keyboard': Near-matches = None
#   - 'multi_language': Near-matches = None
#   - 'multiple_remote': Near-matches = None
#   - 'number_grow': Near-matches = None
#   - 'people_access': Near-matches = None
#   - 'performance_degradation': Near-matches = None
#   - 'planning_purpose': Near-matches = None
#   - 'program_curriculum': Near-matches = None
#   - 'record_per': Near-matches = None
#   - 'report_appointment': Near-matches = None
#   - 'scale_concurrent': Near-matches = None
#   - 'scheduler_reschedule': Near-matches = None
#   - 'scheduling_minimum': Near-matches = None
#   - 'second_poll': Near-matches = None
#   - 'second_submits': Near-matches = None
#   - 'secured_database': Near-matches = None
#   - 'shopping_cart': Near-matches = None
#   - 'sign_creating': Near-matches = None
#   - 'site_detail': Near-matches = None
#   - 'specify_custom': Near-matches = None
#   - 'take_min': Near-matches = None
#   - 'trusted_trusted': Near-matches = None
#   - 'used_estimate': Near-matches = None
#   - 'used_novice': Near-matches = None
#   - 'valid_invalid': Near-matches = None
#   - 'vehicle_vehicle': Near-matches = None
#   - 'viewing_period': Near-matches = None
#   - 'warn_eca': Near-matches = None
#   - 'website': Near-matches = ['site', 'sit', 'si', 'web']
#   - 'website_minute': Near-matches = None
#   - 'window_linux': Near-matches = None
#   - 'window_operating': Near-matches = None
#   - 'window_server': Near-matches = None
# --------------------------------------------------
#
#
# --- Checking Seed Word Survival in Dictionary ---
# WARNING: 63 seed words are NOT in the dictionary after filtering and will be ignored:
# ['access_attempt', 'access_constraint', 'added_minute', 'application_concurrent', 'audit_report', 'authenticated_authorized', 'capable_processing', 'cater_simultaneous', 'collision_estimate', 'customer_installation', 'database', 'dba_two', 'depends_medium', 'display_confirmation', 'end_may', 'estimator_recycled', 'familiar_website', 'feedback_necessary', 'feel_satisfied', 'filesystems']
# ... and 43 more.
# --------------------------------------------------

# %% [markdown]
# Validate Seed Words and Prepare ETA

# %%
logging.info("Started validating seed words")
seed_word_ids = {
    topic: [dictionary.token2id[word] for word in words if word in dictionary.token2id]
    for topic, words in seed_words.items()
}
for topic, ids in seed_word_ids.items():
    logging.info(f"Topic {topic}: {len(ids)}/{len(seed_words[topic])} seed words in dictionary")
    if not ids:
        logging.warning(f"No seed words for {topic} found in dictionary. Topic may be misaligned.")
logging.info("Completed validating seed words")

topic_name_to_id = {name: idx for idx, name in enumerate(seed_words.keys())}
print("\nTopic Name to Integer ID Mapping:")
print(topic_name_to_id)

num_topics = len(seed_words)
num_words = len(dictionary)
eta = np.ones((num_topics, num_words)) * 0.01
for topic_name, seed_word_ids_in_topic in seed_word_ids.items():
    topic_id = topic_name_to_id[topic_name]
    for word_id in seed_word_ids_in_topic:
        eta[topic_id][word_id] = 500.0
# Out:
# Topic Name to Integer ID Mapping:
# {'F': 0, 'FT': 1, 'PE': 2, 'PO': 3, 'SC': 4, 'SE': 5, 'US': 6}

# %% [markdown]
# Train LDA Model

# %%
logging.info("Started creating BoW corpus")
corpus = [dictionary.doc2bow(text) for text in tokenized_reviews]
logging.info("Completed creating BoW corpus")

logging.info("Started training LDA model")
print("\nTraining LDA model...")
lda_model = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    passes=20,
    alpha=0.01/num_topics,
    iterations=400,
    eta=eta,
    random_state=42,
    minimum_probability=0.05,
    per_word_topics=True,
    decay=0.7,
    offset=50.0
)
logging.info("Completed training LDA model")
print("Training complete.")
# Out:
# Training LDA model...
# Training complete.

# %% [markdown]
# Save Models

# %%
logging.info("Saving LDA model, dictionary, and bigram model")
lda_model.save('models/lda_model')
dictionary.save('models/dictionary')
bigram_phraser.save('models/bigram_phraser')
logging.info("Saved LDA model, dictionary, and bigram models")

# %% [markdown]
# Analyze Topics and Coherence

# %%
logging.info("Computing per-topic coherence scores")
print("\n--- Per-Topic Coherence Scores ---")
coherence_model = CoherenceModel(
    model=lda_model,
    texts=tokenized_reviews,
    dictionary=dictionary,
    coherence='c_v',
    topn=10,
    window_size=50
)
per_topic_coherence = coherence_model.get_coherence_per_topic()
id_to_topic_name = {v: k for k, v in topic_name_to_id.items()}
for i, score in enumerate(per_topic_coherence):
    topic_name = id_to_topic_name[i]
    logging.info(f"Topic #{i} ({topic_name}): C_v Score = {score:.4f}")
    print(f"Topic #{i}: {topic_name} - C_v Score = {score:.4f}")
print("------------------------------------\n")

logging.info("Discovered Topics (Top 30 words):")
print("\n--- Deeper Dive into Discovered Topics (Top 30 words) ---")
for i in range(num_topics):
    topic_name = id_to_topic_name[i]
    topic_words_probs = lda_model.show_topic(i, topn=30)
    topic_words = [word for word, prob in topic_words_probs]
    log_message = f"Topic #{i} ({topic_name}): {', '.join(topic_words)}"
    logging.info(log_message)
    print(f"\nTopic #{i}: {topic_name}")
    print(topic_words)
print("----------------------------------------------------------\n")
# Out:
# --- Per-Topic Coherence Scores ---
# Topic #0: F - C_v Score = 0.6777
# Topic #1: FT - C_v Score = 0.4564
# Topic #2: PE - C_v Score = 0.6624
# Topic #3: PO - C_v Score = 0.3651
# Topic #4: SC - C_v Score = 0.3920
# Topic #5: SE - C_v Score = 0.5760
# Topic #6: US - C_v Score = 0.4831
# ------------------------------------
#
#
# --- Deeper Dive into Discovered Topics (Top 30 words) ---
#
# Topic #0: F
# ['better', 'practice', 'little', 'need', 'overall', 'code', 'video', 'however', 'program', 'assignment', 'clear', 'quiz', 'instructor', 'covered', 'nice', 'enough', 'practical', 'basic', 'explanation', 'clearly', 'quite', 'lecture', 'understanding', 'used', 'example', 'student', 'topic', 'provided', 'introduction', 'detail']
#
# Topic #1: FT
# ['amazing', 'awesome', 'love', 'instructor', 'experience', 'professor', 'teacher', 'teaching', 'wonderful', 'learnt', 'learned', 'best', 'fun', 'chuck', 'prof', 'everything', 'interesting', 'taught', 'fantastic', 'made', 'continue', 'team', 'sir', 'python', 'opportunity', 'happy', 'absolutely', 'best_ever', 'making', 'lot']
#
# Topic #2: PE
# ['take', 'complete', 'found', 'difficult', 'hard', 'still', 'though', 'dont', 'feel', 'interesting', 'people', 'need', 'find', 'something', 'little', 'took', 'read', 'time', 'didnt', 'made', 'however', 'learned', 'got', 'hope', 'felt', 'taking', 'long', 'certificate', 'know', 'better']
#
# Topic #3: PO
# ['learned', 'informative', 'interesting', 'best', 'platform', 'ever', 'writing', 'environment', 'web', 'effective', 'enjoy', 'end', 'organized', 'brain', 'fun', 'far', 'nice', 'looking_forward', 'lesson', 'therefore', 'food', 'next', 'enhance', 'interface', 'entertaining', 'popular', 'wide', 'found', 'professional', 'communication']
#
# Topic #4: SC
# ['excellent', 'interesting', 'practical', 'clear', 'follow', 'excel', 'informative', 'highly', 'professor', 'highly_recommend', 'engaging', 'structured', 'subject', 'introduction', 'simple', 'extremely', 'insightful', 'relevant', 'teaching', 'detailed', 'enjoyable', 'topic', 'comprehensive', 'presentation', 'designed', 'fun', 'teacher', 'concise', 'cloud', 'university']
#
# Topic #5: SE
# ['life', 'different', 'world', 'people', 'better', 'business', 'important', 'future', 'learned', 'know', 'understanding', 'career', 'improve', 'interesting', 'research', 'project', 'marketing', 'perspective', 'history', 'gave', 'job', 'design', 'take', 'big', 'management', 'process', 'study', 'field', 'want', 'thinking']
#
# Topic #6: US
# ['python', 'machine', 'basic', 'start', 'introduction', 'science', 'nice', 'excellent', 'language', 'deep', 'understanding', 'beginner', 'best', 'field', 'introductory', 'want', 'know', 'people', 'training', 'perfect', 'overview', 'recommend', 'experience', 'background', 'anyone', 'world', 'someone', 'starting', 'interested', 'simple']
# ----------------------------------------------------------

# %% [markdown]
# Verify Seed Word Probabilities (Detailed)

# %%
print("\n--- Verifying Seed Word Probabilities and Ranks in Final Model ---")
logging.info("Verifying Seed Word Probabilities and Ranks in Final Model")
for topic_name, words in seed_words.items():
    topic_id = topic_name_to_id[topic_name]
    print(f"\nAssigned Topic: {topic_name} (ID: {topic_id})")
    logging.info(f"Assigned Topic: {topic_name} (ID: {topic_id})")
    
    for word in words:
        if word in dictionary.token2id:
            word_id = dictionary.token2id[word]
            term_topics = lda_model.get_term_topics(word_id, minimum_probability=0.0)
            print(f"  - Seed Word '{word}'")
            logging.info(f"  - Seed Word '{word}'")
            for t_id, prob in term_topics:
                t_name = id_to_topic_name[t_id]
                topic_words_probs = lda_model.show_topic(t_id, topn=len(dictionary))
                word_to_rank = {w: idx + 1 for idx, (w, _) in enumerate(topic_words_probs)}
                rank = word_to_rank.get(word, "N/A")
                log_message = f"    * Topic {t_name} (ID: {t_id}): Probability = {prob:.4f}, Rank = {rank}"
                logging.info(log_message)
                print(log_message)
        else:
            logging.warning(f"Seed Word '{word}' for topic '{topic_name}' was not in the final dictionary.")
            print(f"  - '{word}' (Not in dictionary)")
print("----------------------------------------------------------\n")
# Out:
# --- Verifying Seed Word Probabilities and Ranks in Final Model ---
#
# Assigned Topic: F (ID: 0)
#   - Seed Word 'player'
#     * Topic F (ID: 0): Probability = 0.0012, Rank = 207
#   - Seed Word 'display'
#     * Topic F (ID: 0): Probability = 0.0013, Rank = 189
#   - 'collision_estimate' (Not in dictionary)
#   - Seed Word 'program'
#     * Topic F (ID: 0): Probability = 0.0075, Rank = 9
#   - Seed Word 'request'
#     * Topic F (ID: 0): Probability = 0.0017, Rank = 141
#   - Seed Word 'student'
#     * Topic F (ID: 0): Probability = 0.0049, Rank = 26
#     * Topic FT (ID: 1): Probability = 0.0016, Rank = 122
#     * Topic PE (ID: 2): Probability = 0.0015, Rank = 172
#     * Topic SC (ID: 4): Probability = 0.0005, Rank = 318
#     * Topic SE (ID: 5): Probability = 0.0020, Rank = 112
#     * Topic US (ID: 6): Probability = 0.0011, Rank = 174
#   - Seed Word 'view'
#     * Topic F (ID: 0): Probability = 0.0039, Rank = 44
#     * Topic US (ID: 6): Probability = 0.0008, Rank = 210
#   - Seed Word 'list'
#     * Topic F (ID: 0): Probability = 0.0021, Rank = 111
#   - Seed Word 'site'
#     * Topic F (ID: 0): Probability = 0.0021, Rank = 112
#   - 'modify_relating' (Not in dictionary)
#   - 'estimator_recycled' (Not in dictionary)
#   - 'used_estimate' (Not in dictionary)
#   - 'scheduler_reschedule' (Not in dictionary)
#   - 'shopping_cart' (Not in dictionary)
#   - 'vehicle_vehicle' (Not in dictionary)
#   - 'sign_creating' (Not in dictionary)
#   - 'planning_purpose' (Not in dictionary)
#   - 'specify_custom' (Not in dictionary)
#   - Seed Word 'order'
#     * Topic F (ID: 0): Probability = 0.0043, Rank = 31
#     * Topic PE (ID: 2): Probability = 0.0009, Rank = 256
#   - Seed Word 'game'
#     * Topic F (ID: 0): Probability = 0.0019, Rank = 126
#
# Assigned Topic: FT (ID: 1)
#   - Seed Word 'fault'
#     * Topic FT (ID: 1): Probability = 0.0025, Rank = 78
#   - Seed Word 'failure'
#     * Topic FT (ID: 1): Probability = 0.0024, Rank = 83
#   - Seed Word 'reliability'
#     * Topic FT (ID: 1): Probability = 0.0023, Rank = 86
#   - 'database' (Not in dictionary)
#   - Seed Word 'robust'
#     * Topic FT (ID: 1): Probability = 0.0026, Rank = 75
#   - 'website' (Not in dictionary)
#   - Seed Word 'tablet'
#     * Topic FT (ID: 1): Probability = 0.0023, Rank = 89
#   - Seed Word 'loss'
#     * Topic FT (ID: 1): Probability = 0.0025, Rank = 79
#   - 'filesystems' (Not in dictionary)
#   - Seed Word 'tolerance'
#     * Topic FT (ID: 1): Probability = 0.0022, Rank = 93
#   - 'high_number' (Not in dictionary)
#   - 'report_appointment' (Not in dictionary)
#   - 'warn_eca' (Not in dictionary)
#   - Seed Word 'malicious'
#     * Topic FT (ID: 1): Probability = 0.0022, Rank = 96
#   - Seed Word 'continue'
#     * Topic FT (ID: 1): Probability = 0.0104, Rank = 21
#   - Seed Word 'crash'
#     * Topic FT (ID: 1): Probability = 0.0029, Rank = 66
#   - Seed Word 'main'
#     * Topic FT (ID: 1): Probability = 0.0048, Rank = 38
#     * Topic SE (ID: 5): Probability = 0.0017, Rank = 147
#   - Seed Word 'flag'
#     * Topic FT (ID: 1): Probability = 0.0023, Rank = 88
#   - Seed Word 'compensatory'
#     * Topic FT (ID: 1): Probability = 0.0022, Rank = 97
#   - Seed Word 'less'
#     * Topic F (ID: 0): Probability = 0.0023, Rank = 90
#     * Topic FT (ID: 1): Probability = 0.0035, Rank = 54
#     * Topic PE (ID: 2): Probability = 0.0015, Rank = 166
#
# Assigned Topic: PE (ID: 2)
#   - Seed Word 'second'
#     * Topic PE (ID: 2): Probability = 0.0044, Rank = 32
#   - Seed Word 'response'
#     * Topic PE (ID: 2): Probability = 0.0018, Rank = 133
#   - Seed Word 'minute'
#     * Topic PE (ID: 2): Probability = 0.0024, Rank = 93
#   - Seed Word 'load'
#     * Topic PE (ID: 2): Probability = 0.0017, Rank = 142
#   - Seed Word 'take'
#     * Topic FT (ID: 1): Probability = 0.0054, Rank = 31
#     * Topic PE (ID: 2): Probability = 0.0112, Rank = 1
#     * Topic PO (ID: 3): Probability = 0.0029, Rank = 67
#     * Topic SE (ID: 5): Probability = 0.0049, Rank = 23
#     * Topic US (ID: 6): Probability = 0.0045, Rank = 37
#   - Seed Word 'longer'
#     * Topic PE (ID: 2): Probability = 0.0027, Rank = 75
#   - Seed Word 'connection'
#     * Topic PE (ID: 2): Probability = 0.0018, Rank = 129
#   - Seed Word 'application'
#     * Topic PE (ID: 2): Probability = 0.0025, Rank = 86
#     * Topic SE (ID: 5): Probability = 0.0010, Rank = 243
#     * Topic US (ID: 6): Probability = 0.0024, Rank = 85
#   - 'take_min' (Not in dictionary)
#   - 'depends_medium' (Not in dictionary)
#   - 'second_poll' (Not in dictionary)
#   - 'second_submits' (Not in dictionary)
#   - 'display_confirmation' (Not in dictionary)
#   - 'website_minute' (Not in dictionary)
#   - 'performance_degradation' (Not in dictionary)
#   - 'application_concurrent' (Not in dictionary)
#   - 'maximum_second' (Not in dictionary)
#   - Seed Word 'movie'
#     * Topic PE (ID: 2): Probability = 0.0013, Rank = 180
#   - Seed Word 'complete'
#     * Topic F (ID: 0): Probability = 0.0019, Rank = 122
#     * Topic FT (ID: 1): Probability = 0.0022, Rank = 92
#     * Topic PE (ID: 2): Probability = 0.0098, Rank = 2
#     * Topic SC (ID: 4): Probability = 0.0025, Rank = 97
#     * Topic US (ID: 6): Probability = 0.0028, Rank = 69
#   - Seed Word 'performance'
#     * Topic PE (ID: 2): Probability = 0.0020, Rank = 114
#
# Assigned Topic: PO (ID: 3)
#   - Seed Word 'web'
#     * Topic PO (ID: 3): Probability = 0.0119, Rank = 9
#   - Seed Word 'window'
#     * Topic PO (ID: 3): Probability = 0.0042, Rank = 41
#   - Seed Word 'operating'
#     * Topic PO (ID: 3): Probability = 0.0051, Rank = 32
#   - Seed Word 'environment'
#     * Topic PO (ID: 3): Probability = 0.0120, Rank = 8
#   - Seed Word 'compatible'
#     * Topic PO (ID: 3): Probability = 0.0038, Rank = 49
#   - Seed Word 'portable'
#     * Topic PO (ID: 3): Probability = 0.0037, Rank = 51
#   - Seed Word 'platform'
#     * Topic PO (ID: 3): Probability = 0.0195, Rank = 5
#   - Seed Word 'browser'
#     * Topic PO (ID: 3): Probability = 0.0042, Rank = 40
#   - Seed Word 'therefore'
#     * Topic PO (ID: 3): Probability = 0.0064, Rank = 20
#   - Seed Word 'end'
#     * Topic F (ID: 0): Probability = 0.0026, Rank = 78
#     * Topic PE (ID: 2): Probability = 0.0031, Rank = 61
#     * Topic PO (ID: 3): Probability = 0.0097, Rank = 12
#   - 'window_operating' (Not in dictionary)
#   - 'end_may' (Not in dictionary)
#   - 'window_linux' (Not in dictionary)
#   - 'function_browser' (Not in dictionary)
#   - 'window_server' (Not in dictionary)
#   - Seed Word 'interface'
#     * Topic PO (ID: 3): Probability = 0.0058, Rank = 24
#   - Seed Word 'android'
#     * Topic PO (ID: 3): Probability = 0.0040, Rank = 45
#   - Seed Word 'popular'
#     * Topic PO (ID: 3): Probability = 0.0057, Rank = 26
#   - Seed Word 'usable'
#     * Topic PO (ID: 3): Probability = 0.0044, Rank = 37
#   - Seed Word 'wide'
#     * Topic PO (ID: 3): Probability = 0.0056, Rank = 27
#
# Assigned Topic: SC (ID: 4)
#   - Seed Word 'simultaneous'
#     * Topic SC (ID: 4): Probability = 0.0021, Rank = 112
#   - Seed Word 'number'
#     * Topic SC (ID: 4): Probability = 0.0042, Rank = 49
#     * Topic SE (ID: 5): Probability = 0.0007, Rank = 327
#   - Seed Word 'capable'
#     * Topic SC (ID: 4): Probability = 0.0027, Rank = 84
#   - Seed Word 'handle'
#     * Topic SC (ID: 4): Probability = 0.0037, Rank = 61
#   - Seed Word 'server'
#     * Topic SC (ID: 4): Probability = 0.0025, Rank = 93
#   - Seed Word 'concurrent'
#     * Topic SC (ID: 4): Probability = 0.0020, Rank = 113
#   - Seed Word 'hour'
#     * Topic SC (ID: 4): Probability = 0.0030, Rank = 73
#   - Seed Word 'per'
#     * Topic SC (ID: 4): Probability = 0.0039, Rank = 55
#   - Seed Word 'streaming'
#     * Topic SC (ID: 4): Probability = 0.0022, Rank = 107
#   - Seed Word 'transaction'
#     * Topic SC (ID: 4): Probability = 0.0021, Rank = 109
#   - 'record_per' (Not in dictionary)
#   - 'capable_processing' (Not in dictionary)
#   - 'cater_simultaneous' (Not in dictionary)
#   - 'scale_concurrent' (Not in dictionary)
#   - 'customer_installation' (Not in dictionary)
#   - 'scheduling_minimum' (Not in dictionary)
#   - 'handle_simultaneous' (Not in dictionary)
#   - 'number_grow' (Not in dictionary)
#   - 'multiple_remote' (Not in dictionary)
#   - 'program_curriculum' (Not in dictionary)
#
# Assigned Topic: SE (ID: 5)
#   - Seed Word 'access'
#     * Topic SE (ID: 5): Probability = 0.0042, Rank = 32
#   - Seed Word 'customer'
#     * Topic SE (ID: 5): Probability = 0.0024, Rank = 87
#   - Seed Word 'password'
#     * Topic SE (ID: 5): Probability = 0.0016, Rank = 154
#   - Seed Word 'authorized'
#     * Topic SE (ID: 5): Probability = 0.0016, Rank = 159
#   - Seed Word 'ensure'
#     * Topic SE (ID: 5): Probability = 0.0026, Rank = 75
#   - Seed Word 'login'
#     * Topic SE (ID: 5): Probability = 0.0016, Rank = 153
#   - Seed Word 'security'
#     * Topic SE (ID: 5): Probability = 0.0034, Rank = 46
#   - Seed Word 'log'
#     * Topic SE (ID: 5): Probability = 0.0018, Rank = 128
#   - 'secured_database' (Not in dictionary)
#   - Seed Word 'role'
#     * Topic SE (ID: 5): Probability = 0.0037, Rank = 40
#   - 'audit_report' (Not in dictionary)
#   - 'site_detail' (Not in dictionary)
#   - 'people_access' (Not in dictionary)
#   - 'authenticated_authorized' (Not in dictionary)
#   - 'access_constraint' (Not in dictionary)
#   - 'valid_invalid' (Not in dictionary)
#   - 'trusted_trusted' (Not in dictionary)
#   - 'viewing_period' (Not in dictionary)
#   - 'access_attempt' (Not in dictionary)
#   - Seed Word 'secure'
#     * Topic SE (ID: 5): Probability = 0.0018, Rank = 132
#
# Assigned Topic: US (ID: 6)
#   - Seed Word 'training'
#     * Topic US (ID: 6): Probability = 0.0080, Rank = 19
#   - Seed Word 'page'
#     * Topic US (ID: 6): Probability = 0.0028, Rank = 66
#   - Seed Word 'report'
#     * Topic US (ID: 6): Probability = 0.0023, Rank = 92
#   - Seed Word 'language'
#     * Topic F (ID: 0): Probability = 0.0018, Rank = 129
#     * Topic US (ID: 6): Probability = 0.0178, Rank = 9
#   - Seed Word 'dispute'
#     * Topic US (ID: 6): Probability = 0.0018, Rank = 114
#   - Seed Word 'intuitive'
#     * Topic US (ID: 6): Probability = 0.0052, Rank = 32
#   - 'used_novice' (Not in dictionary)
#   - 'dba_two' (Not in dictionary)
#   - 'feel_satisfied' (Not in dictionary)
#   - 'added_minute' (Not in dictionary)
#   - 'familiar_website' (Not in dictionary)
#   - 'identification_dispute' (Not in dictionary)
#   - 'log_minute' (Not in dictionary)
#   - 'feedback_necessary' (Not in dictionary)
#   - 'multi_language' (Not in dictionary)
#   - 'interface_friendly' (Not in dictionary)
#   - Seed Word 'realtor'
#     * Topic US (ID: 6): Probability = 0.0018, Rank = 115
#   - 'icon_toolbars' (Not in dictionary)
#   - 'mouse_keyboard' (Not in dictionary)
#   - 'manage_scheduling' (Not in dictionary)
# ----------------------------------------------------------

# %% [markdown]
# Compute Coherence Scores

# %%
logging.info("Started computing c_v coherence scores")
window_size = 50

print("\n--- Computing C_v Coherence ---")
logging.info("Computing c_v coherence")

coherence_model = CoherenceModel(
    model=lda_model,
    texts=tokenized_reviews,
    dictionary=dictionary,
    coherence='c_v',
    topn=10,
    window_size=window_size
)

per_topic_coherence = coherence_model.get_coherence_per_topic()
print("\nPer-Topic C_v Scores:")
for i, score in enumerate(per_topic_coherence):
    topic_name = id_to_topic_name[i]
    logging.info(f"Topic #{i} ({topic_name}): C_v Score = {score:.4f}")
    print(f"Topic #{i}: {topic_name} - C_v Score = {score:.4f}")

coherence_score = coherence_model.get_coherence()
logging.info(f"Overall C_v Coherence Score: {coherence_score:.4f}")
print(f"\nOverall C_v Coherence Score: {coherence_score:.4f}")
print("------------------------------------\n")
# Out:
# --- Computing C_v Coherence ---
#
# Per-Topic C_v Scores:
# Topic #0: F - C_v Score = 0.6777
# Topic #1: FT - C_v Score = 0.4564
# Topic #2: PE - C_v Score = 0.6624
# Topic #3: PO - C_v Score = 0.3651
# Topic #4: SC - C_v Score = 0.3920
# Topic #5: SE - C_v Score = 0.5760
# Topic #6: US - C_v Score = 0.4831
#
# Overall C_v Coherence Score: 0.5161
# ------------------------------------

# %%
def compute_coherence_range(lda_model, tokenized_reviews, dictionary, window_size=50, topn_range=(10, 100, 10)):
    """
    Compute C_v coherence scores for a range of topn values.
    
    Parameters:
    - lda_model: Trained LDA model
    - tokenized_reviews: List of tokenized texts
    - dictionary: Gensim dictionary
    - window_size: Window size for coherence calculation
    - topn_range: Tuple of (start, end, step) for topn values
    """
    logging.info("Started computing C_v coherence scores for multiple topn values")
    print("\n--- Computing C_v Coherence for Multiple topn Values ---")
    
    start, end, step = topn_range
    coherence_results = []
    
    for topn in range(start, end + 1, step):
        logging.info(f"Computing C_v coherence for topn={topn}")
        print(f"\nComputing C_v Coherence for topn={topn}")
        
        coherence_model = CoherenceModel(
            model=lda_model,
            texts=tokenized_reviews,
            dictionary=dictionary,
            coherence='c_v',
            topn=topn,
            window_size=window_size
        )
        
        per_topic_coherence = coherence_model.get_coherence_per_topic()
        print(f"\nPer-Topic C_v Scores (topn={topn}):")
        for i, score in enumerate(per_topic_coherence):
            topic_name = id_to_topic_name[i]
            logging.info(f"Topic #{i} ({topic_name}): C_v Score = {score:.4f} (topn={topn})")
            print(f"Topic #{i}: {topic_name} - C_v Score = {score:.4f}")
        
        coherence_score = coherence_model.get_coherence()
        logging.info(f"Overall C_v Coherence Score (topn={topn}): {coherence_score:.4f}")
        print(f"\nOverall C_v Coherence Score (topn={topn}): {coherence_score:.4f}")
        print("-" * 35)
        
        coherence_results.append({
            'topn': topn,
            'per_topic_coherence': per_topic_coherence,
            'overall_coherence': coherence_score
        })
    
    logging.info("Completed computing C_v coherence scores for multiple topn values")
    print("\n--- Completed Computing C_v Coherence for Multiple topn Values ---")
    return coherence_results

# Call the new function
coherence_results = compute_coherence_range(
    lda_model=lda_model,
    tokenized_reviews=tokenized_reviews,
    dictionary=dictionary,
    window_size=50,
    topn_range=(10, 100, 10)
)
# Out:
# --- Computing C_v Coherence for Multiple topn Values ---
#
# Computing C_v Coherence for topn=10
#
# Per-Topic C_v Scores (topn=10):
# Topic #0: F - C_v Score = 0.6777
# Topic #1: FT - C_v Score = 0.4564
# Topic #2: PE - C_v Score = 0.6624
# Topic #3: PO - C_v Score = 0.3651
# Topic #4: SC - C_v Score = 0.3920
# Topic #5: SE - C_v Score = 0.5760
# Topic #6: US - C_v Score = 0.4831
#
# Overall C_v Coherence Score (topn=10): 0.5161
# -----------------------------------
#
# Computing C_v Coherence for topn=20
#
# Per-Topic C_v Scores (topn=20):
# Topic #0: F - C_v Score = 0.5828
# Topic #1: FT - C_v Score = 0.4201
# Topic #2: PE - C_v Score = 0.7377
# Topic #3: PO - C_v Score = 0.3494
# Topic #4: SC - C_v Score = 0.3975
# Topic #5: SE - C_v Score = 0.5152
# Topic #6: US - C_v Score = 0.4430
#
# Overall C_v Coherence Score (topn=20): 0.4922
# -----------------------------------
#
# Computing C_v Coherence for topn=30
#
# Per-Topic C_v Scores (topn=30):
# Topic #0: F - C_v Score = 0.6265
# Topic #1: FT - C_v Score = 0.4081
# Topic #2: PE - C_v Score = 0.7300
# Topic #3: PO - C_v Score = 0.2939
# Topic #4: SC - C_v Score = 0.3781
# Topic #5: SE - C_v Score = 0.5479
# Topic #6: US - C_v Score = 0.4723
#
# Overall C_v Coherence Score (topn=30): 0.4938
# -----------------------------------
#
# Computing C_v Coherence for topn=40
#
# Per-Topic C_v Scores (topn=40):
# Topic #0: F - C_v Score = 0.6698
# Topic #1: FT - C_v Score = 0.4208
# Topic #2: PE - C_v Score = 0.7586
# Topic #3: PO - C_v Score = 0.3076
# Topic #4: SC - C_v Score = 0.3914
# Topic #5: SE - C_v Score = 0.5736
# Topic #6: US - C_v Score = 0.5017
#
# Overall C_v Coherence Score (topn=40): 0.5176
# -----------------------------------
#
# Computing C_v Coherence for topn=50
#
# Per-Topic C_v Scores (topn=50):
# Topic #0: F - C_v Score = 0.6720
# Topic #1: FT - C_v Score = 0.4343
# Topic #2: PE - C_v Score = 0.7742
# Topic #3: PO - C_v Score = 0.3658
# Topic #4: SC - C_v Score = 0.4015
# Topic #5: SE - C_v Score = 0.5745
# Topic #6: US - C_v Score = 0.5377
#
# Overall C_v Coherence Score (topn=50): 0.5371
# -----------------------------------
#
# Computing C_v Coherence for topn=60
#
# Per-Topic C_v Scores (topn=60):
# Topic #0: F - C_v Score = 0.7040
# Topic #1: FT - C_v Score = 0.4533
# Topic #2: PE - C_v Score = 0.7794
# Topic #3: PO - C_v Score = 0.3890
# Topic #4: SC - C_v Score = 0.3904
# Topic #5: SE - C_v Score = 0.5863
# Topic #6: US - C_v Score = 0.5418
#
# Overall C_v Coherence Score (topn=60): 0.5492
# -----------------------------------
#
# Computing C_v Coherence for topn=70
#
# Per-Topic C_v Scores (topn=70):
# Topic #0: F - C_v Score = 0.7185
# Topic #1: FT - C_v Score = 0.4478
# Topic #2: PE - C_v Score = 0.7925
# Topic #3: PO - C_v Score = 0.3892
# Topic #4: SC - C_v Score = 0.3636
# Topic #5: SE - C_v Score = 0.5998
# Topic #6: US - C_v Score = 0.5387
#
# Overall C_v Coherence Score (topn=70): 0.5500
# -----------------------------------
#
# Computing C_v Coherence for topn=80
#
# Per-Topic C_v Scores (topn=80):
# Topic #0: F - C_v Score = 0.7222
# Topic #1: FT - C_v Score = 0.4132
# Topic #2: PE - C_v Score = 0.8009
# Topic #3: PO - C_v Score = 0.3963
# Topic #4: SC - C_v Score = 0.3510
# Topic #5: SE - C_v Score = 0.5951
# Topic #6: US - C_v Score = 0.5385
#
# Overall C_v Coherence Score (topn=80): 0.5453
# -----------------------------------
#
# Computing C_v Coherence for topn=90
#
# Per-Topic C_v Scores (topn=90):
# Topic #0: F - C_v Score = 0.7271
# Topic #1: FT - C_v Score = 0.4638
# Topic #2: PE - C_v Score = 0.8067
# Topic #3: PO - C_v Score = 0.3977
# Topic #4: SC - C_v Score = 0.3685
# Topic #5: SE - C_v Score = 0.5947
# Topic #6: US - C_v Score = 0.5217
#
# Overall C_v Coherence Score (topn=90): 0.5543
# -----------------------------------
#
# Computing C_v Coherence for topn=100
#
# Per-Topic C_v Scores (topn=100):
# Topic #0: F - C_v Score = 0.7374
# Topic #1: FT - C_v Score = 0.5235
# Topic #2: PE - C_v Score = 0.8052
# Topic #3: PO - C_v Score = 0.3996
# Topic #4: SC - C_v Score = 0.3804
# Topic #5: SE - C_v Score = 0.5971
# Topic #6: US - C_v Score = 0.5201
#
# Overall C_v Coherence Score (topn=100): 0.5662
# -----------------------------------
#
# --- Completed Computing C_v Coherence for Multiple topn Values ---

# %% [markdown]
# Assign Topics to Reviews and Save with Topic Probabilities

# %%
logging.info("Started getting topic distributions")
doc_topics = [lda_model.get_document_topics(doc, minimum_probability=0.0) for doc in corpus]
topic_matrix = np.zeros((len(corpus), num_topics))
for i, topics in enumerate(doc_topics):
    for topic_id, prob in topics:
        topic_matrix[i, topic_id] = prob
logging.info("Completed getting topic distributions")

logging.info("Started saving all reviews with topics")
all_topics_df = filtered_df.copy()
all_topics_df['Topic'] = np.argmax(topic_matrix, axis=1)
all_topics_df['topic_name'] = all_topics_df['Topic'].map({v: k for k, v in topic_name_to_id.items()})
all_topics_path = '../../datasets/reviews_with_topic.csv'
all_topics_df[['processed_reviews', 'Topic', 'topic_name']].to_csv(all_topics_path, index=False)
logging.info(f"All reviews with topic assignments saved to {all_topics_path}")
print(f"\nAll reviews with topic assignments saved to {all_topics_path}")

logging.info("Sample of saved data:")
logging.info(all_topics_df[['processed_reviews', 'Topic', 'topic_name']].head(2).to_string())
print("Sample of saved data:")
print(all_topics_df[['processed_reviews', 'Topic', 'topic_name']].head(2))
# Out:
# All reviews with topic assignments saved to ../../datasets/reviews_with_topic.csv
# Sample of saved data:
#                                    processed_reviews  Topic topic_name
# 0  thank much lot good find course like especiall...      2         PE
# 1  reading many negative true certain becomes wai...      2         PE

# %% [markdown]
# Select and Save Pseudo-Labeled Reviews with Topic Probabilities and Entropy Filtering

# %%
logging.info(f"Started selecting reviews with confidence > {threshold} and entropy <= {entropy_threshold}")
selected_reviews = {topic_name: [] for topic_name in seed_words.keys()}
non_selected_reviews = {topic_name: [] for topic_name in seed_words.keys()}
id_to_topic = {v: k for k, v in topic_name_to_id.items()}

# Compute topic entropy for all reviews
entropies = [entropy(probs) for probs in topic_matrix]
logging.info(f"Average topic entropy: {np.mean(entropies):.4f}, Std: {np.std(entropies):.4f}")
print(f"\nAverage topic entropy: {np.mean(entropies):.4f}, Std: {np.std(entropies):.4f}")

for i, (review_text, topic_probs) in enumerate(zip(filtered_df['processed_reviews'], topic_matrix)):
    dominant_topic = np.argmax(topic_probs)
    dominant_prob = topic_probs[dominant_topic]
    topic_name = id_to_topic[dominant_topic]
    review_entropy = entropy(topic_probs)
    review_data = {
        'original_index': valid_indices[i],
        'topic': topic_name,
        'confidence': dominant_prob,
        'text': review_text,
        'topic_probs': ','.join(map(str, topic_probs))
    }
    if dominant_prob > threshold and review_entropy <= entropy_threshold:
        selected_reviews[topic_name].append(review_data)
    else:
        non_selected_reviews[topic_name].append(review_data)
logging.info("Completed selecting reviews")

# Log and print summary
logging.info("High-Confidence Reviews Summary:")
print("\nHigh-Confidence Reviews Summary:")
for topic_name, reviews in selected_reviews.items():
    logging.info(f"Topic {topic_name}: {len(reviews):,} high-confidence reviews selected")
    print(f"Topic {topic_name}: {len(reviews):,} high-confidence reviews selected")

logging.info("Non-High-Confidence Reviews Summary:")
print("\nNon-High-Confidence Reviews Summary:")
for topic_name, reviews in non_selected_reviews.items():
    logging.info(f"Topic {topic_name}: {len(reviews):,} non-high-confidence reviews selected")
    print(f"Topic {topic_name}: {len(reviews):,} non-high-confidence reviews selected")

# Save high-confidence reviews
logging.info("Started saving high-confidence reviews")
selected_data = []
for topic_name, reviews in selected_reviews.items():
    for rev in reviews:
        selected_data.append({
            'original_index': rev['original_index'],
            'topic': rev['topic'],
            'confidence': rev['confidence'],
            'text': rev['text'],
            'topic_probs': rev['topic_probs']
        })
selected_df = pd.DataFrame(selected_data)
selected_df.to_csv(output_path, index=False)
logging.info(f"High-confidence pseudo-labeled reviews saved to {output_path}")
print(f"\nHigh-confidence pseudo-labeled reviews saved to {output_path}")

# Save non-high-confidence reviews
logging.info("Started saving non-high-confidence reviews")
non_selected_data = []
for topic_name, reviews in non_selected_reviews.items():
    for rev in reviews:
        non_selected_data.append({
            'original_index': rev['original_index'],
            'text': rev['text']
        })
non_selected_df = pd.DataFrame(non_selected_data)
non_selected_path = '../../datasets/non_high_confidence_reviews.csv'
non_selected_df.to_csv(non_selected_path, index=False)
logging.info(f"Non-high-confidence reviews saved to {non_selected_path}")
print(f"\nNon-high-confidence reviews saved to {non_selected_path}")
# Out:
# Average topic entropy: 0.6575, Std: 0.4564
#
# High-Confidence Reviews Summary:
# Topic F: 14,048 high-confidence reviews selected
# Topic FT: 15,248 high-confidence reviews selected
# Topic PE: 9,493 high-confidence reviews selected
# Topic PO: 7,800 high-confidence reviews selected
# Topic SC: 15,139 high-confidence reviews selected
# Topic SE: 7,784 high-confidence reviews selected
# Topic US: 16,071 high-confidence reviews selected
#
# Non-High-Confidence Reviews Summary:
# Topic F: 37,184 non-high-confidence reviews selected
# Topic FT: 25,212 non-high-confidence reviews selected
# Topic PE: 35,649 non-high-confidence reviews selected
# Topic PO: 11,593 non-high-confidence reviews selected
# Topic SC: 25,940 non-high-confidence reviews selected
# Topic SE: 29,987 non-high-confidence reviews selected
# Topic US: 30,348 non-high-confidence reviews selected
#
# High-confidence pseudo-labeled reviews saved to ../../datasets/selected_pseudo_labeled.csv
#
# Non-high-confidence reviews saved to ../../datasets/non_high_confidence_reviews.csv
